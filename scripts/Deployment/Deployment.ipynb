# %% [markdown]
# ## Carga de datos

# %%
# %%capture
# !pip install mlflow

# %%
import mlflow
import os

# %%
command = """
mlflow server \
        --backend-store-uri sqlite:///tracking.db \
        --default-artifact-root file:mlruns \
        -p 5000 &
"""
get_ipython().system_raw(command)

# %%
# %%capture
# !pip install kagglehub[pandas-dataset]
# !pip install optuna
# !pip install keras
# !pip install pyngrok

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import itertools
import kagglehub
from kagglehub import KaggleDatasetAdapter
import optuna
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import keras
from sklearn.metrics import classification_report, accuracy_score
import mlflow
import os
from pyngrok import ngrok


from sklearn.model_selection import train_test_split

# %%
SEED = 7
token = "2zbl0dEaBIwHYbdy8mg0wAmtd7z_3LPkpSEY88zSz53BdUUbg" # Agregue el token dentro de las comillas
os.environ["NGROK_TOKEN"] = token

# %%
# !ngrok authtoken $NGROK_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
ngrok.connect(5000, "http")
mlflow.set_tracking_uri("http://localhost:5000")
exp_id = mlflow.create_experiment(name="Prediction_addicted", artifact_location="mlruns/")

# %%
file_path = "Students Social Media Addiction.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "adilshamim8/social-media-addiction-vs-relationships",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("Columns:", df.columns)
# Out:
# /tmp/ipython-input-10-1368852353.py:4: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# Columns: Index(['Student_ID', 'Age', 'Gender', 'Academic_Level', 'Country',
#        'Avg_Daily_Usage_Hours', 'Most_Used_Platform',
#        'Affects_Academic_Performance', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score'],
#       dtype='object')

# %% [markdown]
# ## Preprocesamiento

# %%
df = df.drop(columns=['Student_ID']).drop_duplicates()
X=df.drop(columns=['Addicted_Score'])
y=df['Addicted_Score']

# %%
X['Academic_Level'].unique()
y.unique()
# Out:
# array([8, 3, 9, 4, 7, 2, 5, 6])

# %%
#Mapping academic levels
X["Academic_Level"] = X["Academic_Level"].replace({
    "Undergraduate": 2,
    "Graduate": 3,
    "High School": 1
})
# Out:
# /tmp/ipython-input-13-3165889170.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X["Academic_Level"] = X["Academic_Level"].replace({

# %%
X_cat = X.select_dtypes(include=['object'])
X_num = X.select_dtypes(exclude=['object'])

# %%
X_cat_encoded = pd.get_dummies(X_cat, drop_first=True)
X_cat_encoded
# Out:
#      Gender_Male  Country_Albania  Country_Andorra  Country_Argentina  \
# 0          False            False            False              False
# 1           True            False            False              False
# 2          False            False            False              False
# 3           True            False            False              False
# 4           True            False            False              False
# ..           ...              ...              ...                ...
# 700        False            False            False              False
# 701         True            False            False              False
# 702        False            False            False              False
# 703         True            False            False              False
# 704        False            False            False              False
#
#      Country_Armenia  Country_Australia  Country_Austria  Country_Azerbaijan  \
# 0              False              False            False               False
# 1              False              False            False               False
# 2              False              False            False               False
# 3              False              False            False               False
# 4              False              False            False               False
# ..               ...                ...              ...                 ...
# 700            False              False            False               False
# 701            False              False            False               False
# 702            False              False            False               False
# 703            False              False            False               False
# 704            False              False            False               False
#
#      Country_Bahamas  Country_Bahrain  ...  Most_Used_Platform_Snapchat  \
# 0              False            False  ...                        False
# 1              False            False  ...                        False
# 2              False            False  ...                        False
# 3              False            False  ...                        False
# 4              False            False  ...                        False
# ..               ...              ...  ...                          ...
# 700            False            False  ...                        False
# 701            False            False  ...                        False
# 702            False            False  ...                        False
# 703            False            False  ...                        False
# 704            False            False  ...                        False
#
#      Most_Used_Platform_TikTok  Most_Used_Platform_Twitter  \
# 0                        False                       False
# 1                        False                        True
# 2                         True                       False
# 3                        False                       False
# 4                        False                       False
# ..                         ...                         ...
# 700                       True                       False
# 701                      False                       False
# 702                      False                       False
# 703                      False                        True
# 704                      False                       False
#
#      Most_Used_Platform_VKontakte  Most_Used_Platform_WeChat  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ..                            ...                        ...
# 700                         False                      False
# 701                         False                      False
# 702                         False                       True
# 703                         False                      False
# 704                         False                      False
#
#      Most_Used_Platform_WhatsApp  Most_Used_Platform_YouTube  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                        True
# 4                          False                       False
# ..                           ...                         ...
# 700                        False                       False
# 701                        False                       False
# 702                        False                       False
# 703                        False                       False
# 704                        False                       False
#
#      Affects_Academic_Performance_Yes  Relationship_Status_In Relationship  \
# 0                                True                                 True
# 1                               False                                False
# 2                                True                                False
# 3                               False                                False
# 4                                True                                 True
# ..                                ...                                  ...
# 700                             False                                 True
# 701                              True                                False
# 702                              True                                 True
# 703                             False                                False
# 704                              True                                False
#
#      Relationship_Status_Single
# 0                         False
# 1                          True
# 2                         False
# 3                          True
# 4                         False
# ..                          ...
# 700                       False
# 701                        True
# 702                       False
# 703                        True
# 704                        True
#
# [704 rows x 124 columns]

# %%
X_final = pd.concat([X_num, X_cat_encoded], axis=1)
X_final
# Out:
#      Age  Academic_Level  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# 0     19               2                    5.2                    6.5
# 1     22               3                    2.1                    7.5
# 2     20               2                    6.0                    5.0
# 3     18               1                    3.0                    7.0
# 4     21               3                    4.5                    6.0
# ..   ...             ...                    ...                    ...
# 700   20               2                    4.7                    7.2
# 701   23               3                    6.8                    5.9
# 702   21               2                    5.6                    6.7
# 703   24               3                    4.3                    7.5
# 704   19               2                    6.2                    6.3
#
#      Mental_Health_Score  Conflicts_Over_Social_Media  Gender_Male  \
# 0                      6                            3        False
# 1                      8                            0         True
# 2                      5                            4        False
# 3                      7                            1         True
# 4                      6                            2         True
# ..                   ...                          ...          ...
# 700                    7                            2        False
# 701                    4                            5         True
# 702                    6                            3        False
# 703                    8                            2         True
# 704                    5                            4        False
#
#      Country_Albania  Country_Andorra  Country_Argentina  ...  \
# 0              False            False              False  ...
# 1              False            False              False  ...
# 2              False            False              False  ...
# 3              False            False              False  ...
# 4              False            False              False  ...
# ..               ...              ...                ...  ...
# 700            False            False              False  ...
# 701            False            False              False  ...
# 702            False            False              False  ...
# 703            False            False              False  ...
# 704            False            False              False  ...
#
#      Most_Used_Platform_Snapchat  Most_Used_Platform_TikTok  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 700                        False                       True
# 701                        False                      False
# 702                        False                      False
# 703                        False                      False
# 704                        False                      False
#
#      Most_Used_Platform_Twitter  Most_Used_Platform_VKontakte  \
# 0                         False                         False
# 1                          True                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
# ..                          ...                           ...
# 700                       False                         False
# 701                       False                         False
# 702                       False                         False
# 703                        True                         False
# 704                       False                         False
#
#      Most_Used_Platform_WeChat  Most_Used_Platform_WhatsApp  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# ..                         ...                          ...
# 700                      False                        False
# 701                      False                        False
# 702                       True                        False
# 703                      False                        False
# 704                      False                        False
#
#      Most_Used_Platform_YouTube  Affects_Academic_Performance_Yes  \
# 0                         False                              True
# 1                         False                             False
# 2                         False                              True
# 3                          True                             False
# 4                         False                              True
# ..                          ...                               ...
# 700                       False                             False
# 701                       False                              True
# 702                       False                              True
# 703                       False                             False
# 704                       False                              True
#
#      Relationship_Status_In Relationship  Relationship_Status_Single
# 0                                   True                       False
# 1                                  False                        True
# 2                                  False                       False
# 3                                  False                        True
# 4                                   True                       False
# ..                                   ...                         ...
# 700                                 True                       False
# 701                                False                        True
# 702                                 True                       False
# 703                                False                        True
# 704                                False                        True
#
# [704 rows x 130 columns]

# %%
x_test , x_train , y_test , y_train  = train_test_split(X_final , y, test_size=0.7, random_state=7)
x_val , x_test , y_val , y_test  = train_test_split( x_test , y_test , test_size=0.5, random_state=7)

# %%
x_train.shape , y_train.shape , x_test.shape , y_test.shape , x_val.shape , y_val.shape
# Out:
# ((493, 130), (493,), (106, 130), (106,), (105, 130), (105,))

# %% [markdown]
# ## Bosque de decisión

# %%
def objective_RF(trial):
    n_estimators = trial.suggest_int("n_estimators", 10, 200)
    max_depth = trial.suggest_int("max_depth", 5, 15)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 5)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 2)
    criterion = trial.suggest_categorical("criterion", ['gini','entropy'])
    model = RandomForestClassifier(
          n_estimators=n_estimators
          ,max_depth=max_depth
          ,min_samples_split=min_samples_split
          ,min_samples_leaf=min_samples_leaf
          ,criterion=criterion
          ,random_state=SEED
          ).fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = accuracy_score(y_test, y_pred)
    return score

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///hp.db",
    study_name="RandomForest",
    load_if_exists=True,
    )

study.optimize(func=objective_RF, n_trials=100, n_jobs=-1)
# Out:
# [I 2025-07-24 02:01:07,155] A new study created in RDB with name: RandomForest
# [I 2025-07-24 02:01:07,515] Trial 1 finished with value: 0.8962264150943396 and parameters: {'n_estimators': 14, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 1 with value: 0.8962264150943396.
# [I 2025-07-24 02:01:07,845] Trial 2 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 33, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:08,028] Trial 0 finished with value: 0.839622641509434 and parameters: {'n_estimators': 178, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:08,538] Trial 3 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 144, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:08,740] Trial 4 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 152, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:08,995] Trial 5 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 88, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:09,180] Trial 6 finished with value: 0.8867924528301887 and parameters: {'n_estimators': 70, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:09,510] Trial 7 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 102, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:09,565] Trial 8 finished with value: 0.8679245283018868 and parameters: {'n_estimators': 58, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:10,207] Trial 9 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 153, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:10,217] Trial 10 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 102, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:10,481] Trial 11 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 14, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:10,589] Trial 12 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 12, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:10,883] Trial 13 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 51, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:11,095] Trial 14 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 60, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:11,352] Trial 15 finished with value: 0.8962264150943396 and parameters: {'n_estimators': 75, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:11,575] Trial 16 finished with value: 0.9339622641509434 and parameters: {'n_estimators': 85, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:11,772] Trial 17 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 37, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:11,916] Trial 18 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 37, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:12,477] Trial 19 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 123, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:12,658] Trial 20 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 121, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:12,982] Trial 22 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 27, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:13,138] Trial 21 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 127, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:13,347] Trial 23 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 30, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:13,525] Trial 24 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 31, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:13,731] Trial 25 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 46, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:13,989] Trial 26 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 48, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:14,520] Trial 28 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 84, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:14,660] Trial 27 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 193, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:14,848] Trial 29 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 11, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:14,930] Trial 30 finished with value: 0.8207547169811321 and parameters: {'n_estimators': 10, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:15,219] Trial 32 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 21, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:15,260] Trial 31 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 22, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:15,542] Trial 33 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 40, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:15,754] Trial 34 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 40, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:15,845] Trial 35 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 19, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:16,198] Trial 37 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 12, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:16,304] Trial 36 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 72, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:16,820] Trial 38 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 61, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:17,571] Trial 39 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 170, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:17,954] Trial 40 finished with value: 0.9245283018867925 and parameters: {'n_estimators': 159, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:18,338] Trial 41 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 88, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:18,520] Trial 42 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 47, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:18,929] Trial 43 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 53, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:19,230] Trial 44 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 64, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:19,437] Trial 45 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 64, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:19,549] Trial 46 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 28, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:20,695] Trial 47 finished with value: 0.9245283018867925 and parameters: {'n_estimators': 111, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:20,705] Trial 48 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 93, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:21,263] Trial 49 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 20, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:21,426] Trial 50 finished with value: 0.8490566037735849 and parameters: {'n_estimators': 19, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:22,144] Trial 52 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 79, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:22,501] Trial 51 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 134, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:23,062] Trial 53 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 36, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:23,240] Trial 54 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 38, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:23,512] Trial 55 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 55, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:23,739] Trial 56 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 56, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:24,140] Trial 57 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 101, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:24,334] Trial 58 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 96, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:24,588] Trial 59 finished with value: 0.8962264150943396 and parameters: {'n_estimators': 69, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:24,747] Trial 60 finished with value: 0.9056603773584906 and parameters: {'n_estimators': 26, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 2 with value: 0.9528301886792453.
# [I 2025-07-24 02:01:24,862] Trial 61 finished with value: 0.9622641509433962 and parameters: {'n_estimators': 26, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:25,161] Trial 62 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 45, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:25,240] Trial 63 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 32, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:25,548] Trial 65 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 16, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:25,590] Trial 64 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 31, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:25,996] Trial 67 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 51, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:26,022] Trial 66 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 51, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:26,302] Trial 68 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 24, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:26,353] Trial 69 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 10, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:26,735] Trial 70 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 45, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:26,902] Trial 71 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 80, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:27,133] Trial 72 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 37, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:27,294] Trial 73 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 35, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:27,463] Trial 74 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 16, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:27,638] Trial 75 finished with value: 0.9339622641509434 and parameters: {'n_estimators': 16, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:27,883] Trial 76 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 42, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:28,044] Trial 77 finished with value: 0.8490566037735849 and parameters: {'n_estimators': 42, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:28,285] Trial 78 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 26, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:28,725] Trial 80 finished with value: 0.8679245283018868 and parameters: {'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:28,732] Trial 79 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 114, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:29,066] Trial 81 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 32, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:29,167] Trial 82 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 31, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:29,456] Trial 83 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 22, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:29,659] Trial 84 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 23, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:30,135] Trial 85 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 66, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:30,351] Trial 86 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 68, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:30,507] Trial 87 finished with value: 0.9339622641509434 and parameters: {'n_estimators': 16, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:30,777] Trial 88 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 13, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:31,261] Trial 89 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 73, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:31,292] Trial 90 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 39, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:33,166] Trial 92 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 135, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:33,240] Trial 91 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 139, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:34,361] Trial 93 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 114, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:34,517] Trial 94 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 121, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:35,166] Trial 96 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 28, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:35,474] Trial 95 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 129, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:35,666] Trial 97 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 51, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:35,920] Trial 98 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 49, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.
# [I 2025-07-24 02:01:36,258] Trial 99 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 193, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 61 with value: 0.9622641509433962.

# %%
params = study.best_params
print(params)
# Out:
# {'n_estimators': 26, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}

# %%
with mlflow.start_run(
        run_name="RF_Optuna", experiment_id=exp_id
        ) as run:

    model = RandomForestClassifier(**params).fit(x_train, y_train)
    acc = accuracy_score(y_val, model.predict(x_val))
    mlflow.sklearn.log_model(
        model,
        "model",
        registered_model_name="Prediction_addicted",
        input_example = x_train.sample(1)
    )
    mlflow.log_params(params)
    mlflow.log_metrics({
        "accuracy": acc
        })
# Out:
# 2025/07/24 02:01:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Successfully registered model 'Prediction_addicted'.
# 2025/07/24 02:01:45 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Prediction_addicted, version 1
# Created version '1' of model 'Prediction_addicted'.
# 🏃 View run RF_Optuna at: http://localhost:5000/#/experiments/1/runs/ed3f6da9537849d9a4a765784d50b080
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
best_model  = mlflow.sklearn.load_model(f"models:/Prediction_addicted/latest")
report = classification_report(y_val, best_model.predict(x_val))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       0.94      1.00      0.97        16
#            6       1.00      0.92      0.96        13
#            7       1.00      1.00      1.00        32
#            8       0.97      1.00      0.98        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.98       105
#    macro avg       0.99      0.97      0.97       105
# weighted avg       0.98      0.98      0.98       105

# %%
params = {'n_estimators':range(50,101,10), 'criterion':['gini','entropy'] }
forest = RandomForestClassifier()
grid = GridSearchCV(forest, params, cv=5, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.3s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.3s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.2s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.2s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.2s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.2s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.2s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': range(50, 101, 10)},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 50}

# %%
print(classification_report(y_val, grid.predict(x_val)))
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        13
#            7       1.00      1.00      1.00        32
#            8       0.97      1.00      0.98        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.99       105
#    macro avg       1.00      0.98      0.98       105
# weighted avg       0.99      0.99      0.99       105

# %% [markdown]
# Veamos si podemos mejorarlo un poco más

# %%
new_params = {'n_estimators': range(40,60,1), 'criterion': ['entropy']}
forest_2 = RandomForestClassifier()
grid_2 = GridSearchCV(forest_2, new_params, cv=5, verbose=2)
grid_2.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'n_estimators': range(40, 60)},
#              verbose=2)

# %%
grid_2.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 52}

# %%
with mlflow.start_run(
        run_name="RF_GS", experiment_id=exp_id
        ) as run:

    model = RandomForestClassifier(**grid_2.best_params_).fit(x_train, y_train)
    acc = accuracy_score(y_val, model.predict(x_val))
    mlflow.sklearn.log_model(
        model,
        "model",
        registered_model_name="Prediction_addicted_2",
        input_example = x_train.sample(1)
    )
    mlflow.log_params(grid_2.best_params_)
    mlflow.log_metrics({
        "accuracy": acc
        })
# Out:
# 2025/07/24 02:02:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Successfully registered model 'Prediction_addicted_2'.
# 2025/07/24 02:02:09 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Prediction_addicted_2, version 1
# Created version '1' of model 'Prediction_addicted_2'.
# 🏃 View run RF_GS at: http://localhost:5000/#/experiments/1/runs/f9b366295e3e4592ab2d9ac3e564db04
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
best_model  = mlflow.sklearn.load_model(f"models:/Prediction_addicted_2/latest")
report = classification_report(y_val, best_model.predict(x_val))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        13
#            7       1.00      1.00      1.00        32
#            8       0.97      1.00      0.98        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.99       105
#    macro avg       1.00      0.98      0.98       105
# weighted avg       0.99      0.99      0.99       105

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# Finalmente, intentamos con una red neuronal sencilla

# %%
y_train_encoded = pd.get_dummies(y_train, drop_first=False)
y_val_encoded = pd.get_dummies(y_val, drop_first=False)
y_test_encoded = pd.get_dummies(y_test, drop_first=False)

print("Shape of y_train after one-hot encoding:", y_train_encoded.shape)
print("Shape of y_val after one-hot encoding:", y_val_encoded.shape)
print("Shape of y_test after one-hot encoding:", y_test_encoded.shape)
# Out:
# Shape of y_train after one-hot encoding: (493, 7)
# Shape of y_val after one-hot encoding: (105, 7)
# Shape of y_test after one-hot encoding: (106, 8)

# %% [markdown]
# Para asegurar la compatibilidad del experimento y considerando que hay muy pocos registros de 'addicted score' 2 (tan pocos que todos quedaron en el split test), se eliminarán esos registros.

# %%
NN = keras.models.Sequential()
NN.add(keras.layers.Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
NN.add(keras.layers.Dense(7, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
NN.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['precision', 'recall'])

# %%
# %%capture
NN.fit(x_train, y_train_encoded, epochs=100, validation_data=(x_val, y_val_encoded))

# %%
y_test_encoded.drop(2, axis=1, inplace=True)
y_test_encoded.shape
# Out:
# (106, 7)

# %%
NN.evaluate(x_test, y_test_encoded)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2195 - precision: 0.9528 - recall: 0.9583
# [0.2618859112262726, 0.9339622855186462, 0.9428571462631226]

# %% [markdown]
# Como se puede ver, la red neuronal se desempeña bien, pero el bosque de decisión le gana por tres puntos porcentuales.

# %% [markdown]
# ## Despliegue

# %%
# !mkdir src

# %%
# %%writefile ./src/mlcli.py
from argparse import ArgumentParser
import mlflow
import pandas
mlflow.set_tracking_uri("http://localhost:5000")

def main():
    parser = ArgumentParser(
            prog="Social Media Addiction Classifier",
            description="CLI para modelo de prediccion de adiccion a redes sociales"
            )
    parser.add_argument("-p", "--filepath", type=str, required=True, help="Ruta al archivo csv que contiene la serie de python")
    args = parser.parse_args()

    if args.filepath:
      try:
        data = pandas.read_csv(args.filepath, header=0).iloc[:,1:]
      except Exception as e:
        print(e)

    model = mlflow.pyfunc.load_model("models:/Prediction_addicted/latest")
    prediction = model.predict(data)
    print(f"El puntaje predicho de adicción es: {prediction}")

if __name__ == "__main__":
    main()
# Out:
# Overwriting ./src/mlcli.py

# %%
x_test.iloc[[3, 7, 10]].to_csv("test.csv")

# %%
# !python ./src/mlcli.py --help
# Out:
# usage: Social Media Addiction Classifier [-h] -p FILEPATH
#
# CLI para modelo de prediccion de adiccion a redes sociales
#
# options:
#   -h, --help            show this help message and exit
#   -p FILEPATH, --filepath FILEPATH
#                         Ruta al archivo csv que contiene la serie de python

# %%
# !python ./src/mlcli.py -p ./test.csv
# Out:
# El puntaje predicho de adicción es: [6 7 4]
