# %% [markdown]
# ## Carga de datos

# %%
# %%capture
# !pip install mlflow

# %%
import mlflow
import os

# %%
command = """
mlflow server \
        --backend-store-uri sqlite:///tracking.db \
        --default-artifact-root file:mlruns \
        -p 5000 &
"""
get_ipython().system_raw(command)

# %%
# %%capture
# !pip install kagglehub[pandas-dataset]
# !pip install optuna
# !pip install keras
# !pip install pyngrok

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import itertools
import kagglehub
from kagglehub import KaggleDatasetAdapter
import optuna
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import keras
from sklearn.metrics import classification_report, accuracy_score
import mlflow
import os
from pyngrok import ngrok


from sklearn.model_selection import train_test_split

# %%
SEED = 7
token = "2zbl0dEaBIwHYbdy8mg0wAmtd7z_3LPkpSEY88zSz53BdUUbg" # Agregue el token dentro de las comillas
os.environ["NGROK_TOKEN"] = token

# %%
# !ngrok authtoken $NGROK_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
ngrok.connect(5000, "http")
mlflow.set_tracking_uri("http://localhost:5000")
exp_id = mlflow.create_experiment(name="Prediction_addicted", artifact_location="mlruns/")

# %%
file_path = "Students Social Media Addiction.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "adilshamim8/social-media-addiction-vs-relationships",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("Columns:", df.columns)
# Out:
# /tmp/ipython-input-9-1368852353.py:4: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# Columns: Index(['Student_ID', 'Age', 'Gender', 'Academic_Level', 'Country',
#        'Avg_Daily_Usage_Hours', 'Most_Used_Platform',
#        'Affects_Academic_Performance', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score'],
#       dtype='object')

# %% [markdown]
# ## Preprocesamiento

# %%
df = df.drop(columns=['Student_ID']).drop_duplicates()
X=df.drop(columns=['Addicted_Score'])
y=df['Addicted_Score']

# %%
X['Academic_Level'].unique()
y.unique()
# Out:
# array([8, 3, 9, 4, 7, 2, 5, 6])

# %%
#Mapping academic levels
X["Academic_Level"] = X["Academic_Level"].replace({
    "Undergraduate": 2,
    "Graduate": 3,
    "High School": 1
})
# Out:
# /tmp/ipython-input-12-3165889170.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X["Academic_Level"] = X["Academic_Level"].replace({

# %%
X_cat = X.select_dtypes(include=['object'])
X_num = X.select_dtypes(exclude=['object'])

# %%
X_cat_encoded = pd.get_dummies(X_cat, drop_first=True)
X_cat_encoded
# Out:
#      Gender_Male  Country_Albania  Country_Andorra  Country_Argentina  \
# 0          False            False            False              False
# 1           True            False            False              False
# 2          False            False            False              False
# 3           True            False            False              False
# 4           True            False            False              False
# ..           ...              ...              ...                ...
# 700        False            False            False              False
# 701         True            False            False              False
# 702        False            False            False              False
# 703         True            False            False              False
# 704        False            False            False              False
#
#      Country_Armenia  Country_Australia  Country_Austria  Country_Azerbaijan  \
# 0              False              False            False               False
# 1              False              False            False               False
# 2              False              False            False               False
# 3              False              False            False               False
# 4              False              False            False               False
# ..               ...                ...              ...                 ...
# 700            False              False            False               False
# 701            False              False            False               False
# 702            False              False            False               False
# 703            False              False            False               False
# 704            False              False            False               False
#
#      Country_Bahamas  Country_Bahrain  ...  Most_Used_Platform_Snapchat  \
# 0              False            False  ...                        False
# 1              False            False  ...                        False
# 2              False            False  ...                        False
# 3              False            False  ...                        False
# 4              False            False  ...                        False
# ..               ...              ...  ...                          ...
# 700            False            False  ...                        False
# 701            False            False  ...                        False
# 702            False            False  ...                        False
# 703            False            False  ...                        False
# 704            False            False  ...                        False
#
#      Most_Used_Platform_TikTok  Most_Used_Platform_Twitter  \
# 0                        False                       False
# 1                        False                        True
# 2                         True                       False
# 3                        False                       False
# 4                        False                       False
# ..                         ...                         ...
# 700                       True                       False
# 701                      False                       False
# 702                      False                       False
# 703                      False                        True
# 704                      False                       False
#
#      Most_Used_Platform_VKontakte  Most_Used_Platform_WeChat  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ..                            ...                        ...
# 700                         False                      False
# 701                         False                      False
# 702                         False                       True
# 703                         False                      False
# 704                         False                      False
#
#      Most_Used_Platform_WhatsApp  Most_Used_Platform_YouTube  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                        True
# 4                          False                       False
# ..                           ...                         ...
# 700                        False                       False
# 701                        False                       False
# 702                        False                       False
# 703                        False                       False
# 704                        False                       False
#
#      Affects_Academic_Performance_Yes  Relationship_Status_In Relationship  \
# 0                                True                                 True
# 1                               False                                False
# 2                                True                                False
# 3                               False                                False
# 4                                True                                 True
# ..                                ...                                  ...
# 700                             False                                 True
# 701                              True                                False
# 702                              True                                 True
# 703                             False                                False
# 704                              True                                False
#
#      Relationship_Status_Single
# 0                         False
# 1                          True
# 2                         False
# 3                          True
# 4                         False
# ..                          ...
# 700                       False
# 701                        True
# 702                       False
# 703                        True
# 704                        True
#
# [704 rows x 124 columns]

# %%
X_final = pd.concat([X_num, X_cat_encoded], axis=1)
X_final
# Out:
#      Age  Academic_Level  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# 0     19               2                    5.2                    6.5
# 1     22               3                    2.1                    7.5
# 2     20               2                    6.0                    5.0
# 3     18               1                    3.0                    7.0
# 4     21               3                    4.5                    6.0
# ..   ...             ...                    ...                    ...
# 700   20               2                    4.7                    7.2
# 701   23               3                    6.8                    5.9
# 702   21               2                    5.6                    6.7
# 703   24               3                    4.3                    7.5
# 704   19               2                    6.2                    6.3
#
#      Mental_Health_Score  Conflicts_Over_Social_Media  Gender_Male  \
# 0                      6                            3        False
# 1                      8                            0         True
# 2                      5                            4        False
# 3                      7                            1         True
# 4                      6                            2         True
# ..                   ...                          ...          ...
# 700                    7                            2        False
# 701                    4                            5         True
# 702                    6                            3        False
# 703                    8                            2         True
# 704                    5                            4        False
#
#      Country_Albania  Country_Andorra  Country_Argentina  ...  \
# 0              False            False              False  ...
# 1              False            False              False  ...
# 2              False            False              False  ...
# 3              False            False              False  ...
# 4              False            False              False  ...
# ..               ...              ...                ...  ...
# 700            False            False              False  ...
# 701            False            False              False  ...
# 702            False            False              False  ...
# 703            False            False              False  ...
# 704            False            False              False  ...
#
#      Most_Used_Platform_Snapchat  Most_Used_Platform_TikTok  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 700                        False                       True
# 701                        False                      False
# 702                        False                      False
# 703                        False                      False
# 704                        False                      False
#
#      Most_Used_Platform_Twitter  Most_Used_Platform_VKontakte  \
# 0                         False                         False
# 1                          True                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
# ..                          ...                           ...
# 700                       False                         False
# 701                       False                         False
# 702                       False                         False
# 703                        True                         False
# 704                       False                         False
#
#      Most_Used_Platform_WeChat  Most_Used_Platform_WhatsApp  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# ..                         ...                          ...
# 700                      False                        False
# 701                      False                        False
# 702                       True                        False
# 703                      False                        False
# 704                      False                        False
#
#      Most_Used_Platform_YouTube  Affects_Academic_Performance_Yes  \
# 0                         False                              True
# 1                         False                             False
# 2                         False                              True
# 3                          True                             False
# 4                         False                              True
# ..                          ...                               ...
# 700                       False                             False
# 701                       False                              True
# 702                       False                              True
# 703                       False                             False
# 704                       False                              True
#
#      Relationship_Status_In Relationship  Relationship_Status_Single
# 0                                   True                       False
# 1                                  False                        True
# 2                                  False                       False
# 3                                  False                        True
# 4                                   True                       False
# ..                                   ...                         ...
# 700                                 True                       False
# 701                                False                        True
# 702                                 True                       False
# 703                                False                        True
# 704                                False                        True
#
# [704 rows x 130 columns]

# %%
x_test , x_train , y_test , y_train  = train_test_split(X_final , y, test_size=0.7, random_state=7)
x_val , x_test , y_val , y_test  = train_test_split( x_test , y_test , test_size=0.5, random_state=7)

# %%
x_train.shape , y_train.shape , x_test.shape , y_test.shape , x_val.shape , y_val.shape
# Out:
# ((493, 130), (493,), (106, 130), (106,), (105, 130), (105,))

# %% [markdown]
# ## Bosque de decisión

# %%
def objective_RF(trial):
    n_estimators = trial.suggest_int("n_estimators", 10, 200)
    max_depth = trial.suggest_int("max_depth", 5, 15)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 5)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 2)
    criterion = trial.suggest_categorical("criterion", ['gini','entropy'])
    model = RandomForestClassifier(
          n_estimators=n_estimators
          ,max_depth=max_depth
          ,min_samples_split=min_samples_split
          ,min_samples_leaf=min_samples_leaf
          ,criterion=criterion
          ,random_state=SEED
          ).fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = accuracy_score(y_test, y_pred)
    return score

# %%
study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///hp.db",
    study_name="RandomForest",
    load_if_exists=True,
    )

study.optimize(func=objective_RF, n_trials=100, n_jobs=-1)
# Out:
# [I 2025-07-18 03:02:14,481] A new study created in RDB with name: RandomForest
# [I 2025-07-18 03:02:15,728] Trial 1 finished with value: 0.9056603773584906 and parameters: {'n_estimators': 51, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'gini'}. Best is trial
 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:57,115] Trial 60 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 39, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:58,011] Trial 62 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 73, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:58,322] Trial 61 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 183, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:58,846] Trial 63 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 82, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:59,203] Trial 64 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 80, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:02:59,903] Trial 65 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 101, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:00,840] Trial 66 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 193, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:01,079] Trial 67 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 121, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:01,353] Trial 68 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 44, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:01,436] Trial 69 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 13, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:01,882] Trial 70 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 53, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:02,666] Trial 71 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 171, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:02,992] Trial 72 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 168, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:03,528] Trial 73 finished with value: 0.9339622641509434 and parameters: {'n_estimators': 133, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:03,832] Trial 74 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 130, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:04,179] Trial 75 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 73, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:04,587] Trial 76 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 95, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:05,383] Trial 77 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 194, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:05,693] Trial 78 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 194, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:06,386] Trial 80 finished with value: 0.9433962264150944 and parameters: {'n_estimators': 64, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:06,538] Trial 79 finished with value: 0.9150943396226415 and parameters: {'n_estimators': 183, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 2, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:07,490] Trial 82 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 117, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:07,570] Trial 81 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 181, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:08,419] Trial 83 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 124, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:08,422] Trial 84 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 105, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:09,011] Trial 85 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 55, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:09,198] Trial 86 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 115, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:09,819] Trial 87 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 111, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:09,981] Trial 88 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 87, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:10,581] Trial 89 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 85, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:11,031] Trial 90 finished with value: 0.9056603773584906 and parameters: {'n_estimators': 143, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:11,952] Trial 91 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 148, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:12,548] Trial 92 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 174, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:13,529] Trial 93 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 173, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:14,036] Trial 94 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 163, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:14,819] Trial 95 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 160, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:15,245] Trial 96 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 187, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:15,893] Trial 98 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 75, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:16,022] Trial 97 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 188, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'gini'}. Best is trial 5 with value: 0.9528301886792453.
# [I 2025-07-18 03:03:16,497] Trial 99 finished with value: 0.9528301886792453 and parameters: {'n_estimators': 153, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}. Best is trial 5 with value: 0.9528301886792453.

# %%
params = study.best_params
print(params)
# Out:
# {'n_estimators': 67, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'entropy'}

# %%
with mlflow.start_run(
        run_name="RF_Optuna", experiment_id=exp_id
        ) as run:

    model = RandomForestClassifier(**params).fit(x_train, y_train)
    acc = accuracy_score(y_val, model.predict(x_val))
    mlflow.sklearn.log_model(
        model,
        "model",
        registered_model_name="Prediction_addicted",
        input_example = x_train.sample(1)
    )
    mlflow.log_params(params)
    mlflow.log_metrics({
        "accuracy": acc
        })
# Out:
# 2025/07/18 03:09:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'Prediction_addicted' already exists. Creating a new version of this model...
# 2025/07/18 03:09:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Prediction_addicted, version 2
# Created version '2' of model 'Prediction_addicted'.
# 🏃 View run RF at: http://localhost:5000/#/experiments/1/runs/6f41c9adbf444d5c963f001f7536962f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
best_model  = mlflow.sklearn.load_model(f"models:/Prediction_addicted/latest")
report = classification_report(y_val, best_model.predict(x_val))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        13
#            7       1.00      1.00      1.00        32
#            8       0.97      1.00      0.98        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.99       105
#    macro avg       1.00      0.98      0.98       105
# weighted avg       0.99      0.99      0.99       105

# %%
params = {'n_estimators':range(50,101,10), 'criterion':['gini','entropy'] }
forest = RandomForestClassifier()
grid = GridSearchCV(forest, params, cv=5, verbose=2)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=50; total time=   0.3s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=60; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.1s
# [CV] END ....................criterion=gini, n_estimators=70; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=80; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ....................criterion=gini, n_estimators=90; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END ...................criterion=gini, n_estimators=100; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=60; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=70; total time=   0.4s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.6s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=80; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.3s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.3s
# [CV] END .................criterion=entropy, n_estimators=90; total time=   0.3s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.3s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.4s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.3s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.3s
# [CV] END ................criterion=entropy, n_estimators=100; total time=   0.4s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': range(50, 101, 10)},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'n_estimators': 70}

# %%
print(classification_report(y_val, grid.predict(x_val)))
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        13
#            7       0.97      1.00      0.98        32
#            8       0.96      0.96      0.96        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.98       105
#    macro avg       0.99      0.97      0.98       105
# weighted avg       0.98      0.98      0.98       105

# %% [markdown]
# Veamos si podemos mejorarlo un poco más

# %%
new_params = {'n_estimators': range(40,60,1), 'criterion': ['entropy']}
forest_2 = RandomForestClassifier()
grid_2 = GridSearchCV(forest_2, new_params, cv=5, verbose=2)
grid_2.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=40; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=41; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=42; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=43; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=44; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=45; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=46; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=47; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=48; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=49; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=50; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=51; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=52; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=53; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=54; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=55; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=56; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=57; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=58; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.2s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# [CV] END .................criterion=entropy, n_estimators=59; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy'],
#                          'n_estimators': range(40, 60)},
#              verbose=2)

# %%
grid_2.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 58}

# %%
with mlflow.start_run(
        run_name="RF_GS", experiment_id=exp_id
        ) as run:

    model = RandomForestClassifier(**grid_2.best_params_).fit(x_train, y_train)
    acc = accuracy_score(y_val, model.predict(x_val))
    mlflow.sklearn.log_model(
        model,
        "model",
        registered_model_name="Prediction_addicted",
        input_example = x_train.sample(1)
    )
    mlflow.log_params(grid_2.best_params_)
    mlflow.log_metrics({
        "accuracy": acc
        })
# Out:
# 2025/07/18 03:13:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'Prediction_addicted' already exists. Creating a new version of this model...
# 2025/07/18 03:13:51 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Prediction_addicted, version 3
# Created version '3' of model 'Prediction_addicted'.
# 🏃 View run RF_GS at: http://localhost:5000/#/experiments/1/runs/3600521e967a4223b51c3e4057931f88
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
best_model  = mlflow.sklearn.load_model(f"models:/Prediction_addicted/latest")
report = classification_report(y_val, best_model.predict(x_val))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        16
#            6       1.00      1.00      1.00        13
#            7       1.00      1.00      1.00        32
#            8       0.97      1.00      0.98        28
#            9       1.00      0.83      0.91         6
#
#     accuracy                           0.99       105
#    macro avg       1.00      0.98      0.98       105
# weighted avg       0.99      0.99      0.99       105

# %% [markdown]
# ## Red neuronal

# %% [markdown]
# Finalmente, intentamos con una red neuronal sencilla

# %%
y_train_encoded = pd.get_dummies(y_train, drop_first=False)
y_val_encoded = pd.get_dummies(y_val, drop_first=False)
y_test_encoded = pd.get_dummies(y_test, drop_first=False)

print("Shape of y_train after one-hot encoding:", y_train_encoded.shape)
print("Shape of y_val after one-hot encoding:", y_val_encoded.shape)
print("Shape of y_test after one-hot encoding:", y_test_encoded.shape)
# Out:
# Shape of y_train after one-hot encoding: (493, 7)
# Shape of y_val after one-hot encoding: (105, 7)
# Shape of y_test after one-hot encoding: (106, 8)

# %% [markdown]
# Para asegurar la compatibilidad del experimento y considerando que hay muy pocos registros de 'addicted score' 2 (tan pocos que todos quedaron en el split test), se eliminarán esos registros.

# %%
NN = keras.models.Sequential()
NN.add(keras.layers.Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
NN.add(keras.layers.Dense(7, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
NN.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['precision', 'recall'])

# %%
# %%capture
NN.fit(x_train, y_train_encoded, epochs=100, validation_data=(x_val, y_val_encoded))
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 2.3987 - precision: 0.0588 - recall: 0.0045 - val_loss: 1.6565 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6432 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5483 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5256 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3916 - precision: 0.6471 - recall: 0.0032 - val_loss: 1.3423 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3126 - precision: 0.7123 - recall: 0.0148 - val_loss: 1.2469 - val_precision: 0.6667 - val_recall: 0.0190
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2078 - precision: 0.7449 - recall: 0.0186 - val_loss: 1.1695 - val_precision: 0.9000 - val_recall: 0.0857
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1182 - precision: 0.7969 - recall: 0.1012 - val_loss: 1.1130 - val_precision: 0.9444 - val_recall: 0.1619
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0639 - precision: 0.7920 - recall: 0.1491 - val_loss: 1.0336 - val_precision: 0.9643 - val_recall: 0.2571
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9968 - precision: 0.8386 - recall: 0.2456 - val_loss: 1.0191 - val_precision: 0.9444 - val_recall: 0.3238
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9272 - precision: 0.8857 - recall: 0.3513 - val_loss: 0.9454 - val_precision: 0.8919 - val_recall: 0.3143
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8931 - precision: 0.8579 - recall: 0.3849 - val_loss: 0.8923 - val_precision: 0.9375 - val_recall: 0.4286
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8615 - precision: 0.9005 - recall: 0.4577 - val_loss: 0.8500 - val_precision: 0.9556 - val_recall: 0.4095
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7902 - precision: 0.9256 - recall: 0.5282 - val_loss: 0.8165 - val_precision: 0.9636 - val_recall: 0.5048
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7628 - precision: 0.9335 - recall: 0.5885 - val_loss: 0.7823 - val_precision: 0.9815 - val_recall: 0.5048
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7391 - precision: 0.9059 - recall: 0.6078 - val_loss: 0.7367 - val_precision: 0.9500 - val_recall: 0.5429
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6827 - precision: 0.9168 - recall: 0.6496 - val_loss: 0.7239 - val_precision: 0.9688 - val_recall: 0.5905
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6428 - precision: 0.9415 - recall: 0.6752 - val_loss: 0.6836 - val_precision: 0.9028 - val_recall: 0.6190
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6186 - precision: 0.9270 - recall: 0.6939 - val_loss: 0.6546 - val_precision: 0.9254 - val_recall: 0.5905
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5906 - precision: 0.9207 - recall: 0.7131 - val_loss: 0.6385 - val_precision: 0.9211 - val_recall: 0.6667
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5775 - precision: 0.9214 - recall: 0.7217 - val_loss: 0.6053 - val_precision: 0.9067 - val_recall: 0.6476
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5506 - precision: 0.9314 - recall: 0.7646 - val_loss: 0.5840 - val_precision: 0.9577 - val_recall: 0.6476
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5278 - precision: 0.9208 - recall: 0.7879 - val_loss: 0.5582 - val_precision: 0.9605 - val_recall: 0.6952
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5096 - precision: 0.9304 - recall: 0.7915 - val_loss: 0.5467 - val_precision: 0.9059 - val_recall: 0.7333
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4636 - precision: 0.9268 - recall: 0.8090 - val_loss: 0.5247 - val_precision: 0.9405 - val_recall: 0.7524
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4573 - precision: 0.9505 - recall: 0.8424 - val_loss: 0.5002 - val_precision: 0.9524 - val_recall: 0.7619
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4516 - precision: 0.9427 - recall: 0.8351 - val_loss: 0.5127 - val_precision: 0.8791 - val_recall: 0.7619
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1392 - precision: 0.9682 - recall: 0.9615 - val_loss: 0.1809 - val_precision: 0.9524 - val_recall: 0.9524
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1356 - precision: 0.9633 - recall: 0.9633 - val_loss: 0.1789 - val_precision: 0.9612 - val_recall: 0.9429
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1307 - precision: 0.9654 - recall: 0.9605 - val_loss: 0.1869 - val_precision: 0.9519 - val_recall: 0.9429
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1197 - precision: 0.9773 - recall: 0.9638 - val_loss: 0.1824 - val_precision: 0.9709 - val_recall: 0.9524
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1168 - precision: 0.9748 - recall: 0.9729 - val_loss: 0.1765 - val_precision: 0.9519 - val_recall: 0.9429
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1180 - precision: 0.9760 - recall: 0.9731 - val_loss: 0.1829 - val_precision: 0.9712 - val_recall: 0.9619
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1148 - precision: 0.9698 - recall: 0.9675 - val_loss: 0.1736 - val_precision: 0.9515 - val_recall: 0.9333
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1026 - precision: 0.9770 - recall: 0.9736 - val_loss: 0.1776 - val_precision: 0.9519 - val_recall: 0.9429
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1101 - precision: 0.9781 - recall: 0.9736 - val_loss: 0.1695 - val_precision: 0.9423 - val_recall: 0.9333
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1338 - precision: 0.9663 - recall: 0.9623 - val_loss: 0.1726 - val_precision: 0.9703 - val_recall: 0.9333
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1234 - precision: 0.9712 - recall: 0.9699 - val_loss: 0.1715 - val_precision: 0.9429 - val_recall: 0.9429
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1097 - precision: 0.9713 - recall: 0.9695 - val_loss: 0.1688 - val_precision: 0.9519 - val_recall: 0.9429
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0946 - precision: 0.9817 - recall: 0.9812 - val_loss: 0.1770 - val_precision: 0.9429 - val_recall: 0.9429
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1033 - precision: 0.9705 - recall: 0.9687 - val_loss: 0.1672 - val_precision: 0.9703 - val_recall: 0.9333
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1035 - precision: 0.9711 - recall: 0.9700 - val_loss: 0.1705 - val_precision: 0.9524 - val_recall: 0.9524
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1207 - precision: 0.9631 - recall: 0.9580 - val_loss: 0.1642 - val_precision: 0.9515 - val_recall: 0.9333
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0864 - precision: 0.9861 - recall: 0.9834 - val_loss: 0.1758 - val_precision: 0.9515 - val_recall: 0.9333
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1062 - precision: 0.9759 - recall: 0.9734 - val_loss: 0.1643 - val_precision: 0.9612 - val_recall: 0.9429
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1035 - precision: 0.9755 - recall: 0.9727 - val_loss: 0.1705 - val_precision: 0.9417 - val_recall: 0.9238
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1011 - precision: 0.9687 - recall: 0.9623 - val_loss: 0.1622 - val_precision: 0.9608 - val_recall: 0.9333
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1012 - precision: 0.9599 - recall: 0.9590 - val_loss: 0.1602 - val_precision: 0.9423 - val_recall: 0.9333
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1035 - precision: 0.9745 - recall: 0.9732 - val_loss: 0.1791 - val_precision: 0.9515 - val_recall: 0.9333
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1005 - precision: 0.9618 - recall: 0.9612 - val_loss: 0.1592 - val_precision: 0.9515 - val_recall: 0.9333

# %%
y_test_encoded.drop(2, axis=1, inplace=True)
y_test_encoded.shape
# Out:
# (106, 7)

# %%
NN.evaluate(x_test, y_test_encoded)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2374 - precision: 0.9456 - recall: 0.9371
# [0.2786245048046112, 0.932692289352417, 0.9238095283508301]

# %% [markdown]
# Como se puede ver, la red neuronal se desempeña bien, pero el bosque de decisión le gana por tres puntos porcentuales.
